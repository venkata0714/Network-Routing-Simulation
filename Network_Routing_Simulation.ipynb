# %%
# Visualize the initial network
visualize_network(G)

# Test Case 1: Run algorithms with source="B" and target="F"
print("\nTest Case 1: Source = 'B', Target = 'F'")
source = "B"
target = "F"

# Run Dijkstra's algorithm
print("\nDijkstra's algorithm:")
dist, prev = dijkstra(G, source)
for node in G.nodes():
    print(f"Distance from {source} to {node}: {dist[node]}")
    if prev[node] is not None:
        path = []
        curr = node
        while curr is not None:
            path.insert(0, curr)
            curr = prev[curr]
        print(f"Path from {source} to {node}: {' -> '.join(path)}")
visualize_network(G, path)

# Run Bellman-Ford algorithm
print("\nBellman-Ford algorithm:")
dist, prev = bellman_ford(G, source)
for node in G.nodes():
    print(f"Distance from {source} to {node}: {dist[node]}")
    if prev[node] is not None:
        path = []
        curr = node
        while curr is not None:
            path.insert(0, curr)
            curr = prev[curr]
        print(f"Path from {source} to {node}: {' -> '.join(path)}")
visualize_network(G, path)

# Run A* algorithm
print("\nA* algorithm:")
dist, prev = astar(G, source, target)
for node in G.nodes():
    print(f"Distance from {source} to {node}: {dist[node]}")
    if prev[node] is not None:
        path = []
        curr = node
        while curr is not None:
            path.insert(0, curr)
            curr = prev[curr]
        print(f"Path from {source} to {node}: {' -> '.join(path)}")
visualize_network(G, path)

# Test Case 2: Run algorithms with source="C" and target="E"
print("\nTest Case 2: Source = 'C', Target = 'E'")
source = "C"
target = "E"

# Run Dijkstra's algorithm
print("\nDijkstra's algorithm:")
dist, prev = dijkstra(G, source)
for node in G.nodes():
    print(f"Distance from {source} to {node}: {dist[node]}")
    if prev[node] is not None:
        path = []
        curr = node
        while curr is not None:
            path.insert(0, curr)
            curr = prev[curr]
        print(f"Path from {source} to {node}: {' -> '.join(path)}")
visualize_network(G, path)

# Run Bellman-Ford algorithm
print("\nBellman-Ford algorithm:")
dist, prev = bellman_ford(G, source)
for node in G.nodes():
    print(f"Distance from {source} to {node}: {dist[node]}")
    if prev[node] is not None:
        path = []
        curr = node
        while curr is not None:
            path.insert(0, curr)
            curr = prev[curr]
        print(f"Path from {source} to {node}: {' -> '.join(path)}")
visualize_network(G, path)

# Run A* algorithm
print("\nA* algorithm:")
dist, prev = astar(G, source, target)
for node in G.nodes():
    print(f"Distance from {source} to {node}: {dist[node]}")
    if prev[node] is not None:
        path = []
        curr = node
        while curr is not None:
            path.insert(0, curr)
            curr = prev[curr]
        print(f"Path from {source} to {node}: {' -> '.join(path)}")
visualize_network(G, path)
# Out:
# Test Case 1: Source = 'B', Target = 'F'
#
# Dijkstra's algorithm:
# Distance from B to A: 3
# Path from B to A: B -> C -> A
# Distance from B to B: 0
# Distance from B to C: 2
# Path from B to C: B -> C
# Distance from B to D: 1
# Path from B to D: B -> D
# Distance from B to E: 4
# Path from B to E: B -> D -> E
# Distance from B to F: 6
# Path from B to F: B -> D -> E -> F
# Bellman-Ford algorithm:
# Distance from B to A: inf
# Distance from B to B: 0
# Distance from B to C: 2
# Path from B to C: B -> C
# Distance from B to D: 1
# Path from B to D: B -> D
# Distance from B to E: 4
# Path from B to E: B -> D -> E
# Distance from B to F: 6
# Path from B to F: B -> D -> E -> F
# A* algorithm:
# Distance from B to A: 5
# Path from B to A: B -> A
# Distance from B to B: 0
# Distance from B to C: 2
# Path from B to C: B -> C
# Distance from B to D: 1
# Path from B to D: B -> D
# Distance from B to E: inf
# Distance from B to F: inf
# Test Case 2: Source = 'C', Target = 'E'
#
# ...
